# %%
from cdt.causality.pairwise import ANM
from cdt.causality.pairwise import CDS
from cdt.causality.pairwise import IGCI
# Out:
# Detecting 1 CUDA device(s).

# %%
import numpy as np

# %%
X = np.random.uniform(size=(100, 10))

# %%
Y = 0.5*X  #+ 0.3*np.random.uniform(size=(100, 10))

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(X, Y)

# %%
method = ANM()
method.predict_proba((X, Y))
# Out:
# 0.0

# %%
method = CDS()
method.predict_proba((X, Y))
# Out:
# 0.023612803979477598

# %%
method = IGCI()
method.predict_proba((X, Y))
# Out:
# 0.30304526590854663
